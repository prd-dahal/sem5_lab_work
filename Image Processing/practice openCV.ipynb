# %%
#shell 1 always run this shell before doing anything in the cells below
import numpy as np
import cv2
import time
import matplotlib.pyplot as plt
try:
    img1=cv2.imread('images\opticalfb.jpg',0)
    img2=cv2.imread('images\camshift_result.jpg',0)
except:
    print("Failed loading")

# %%
#image show
cv2.imshow('window',img1)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
time.sleep(4)
cv2.namedWindow('window',cv2.WINDOW_NORMAL)
cv2.imshow('window',img2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#using matplotlib
plt.imshow(img1,cmap='gray', interpolation='bicubic')
#hide tick values
plt.xticks([]),plt.yticks([])
plt.show()

# %%
img = cv2.ellipse(img1,(256,256),(100,50),0,0,180,255,-1)
cv2.imshow('img',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#operations in images using opencv
print(img1.shape)
print(img1.size)
print(img1.dtype)
# Out:
# (582, 418)
# 243276
# uint8

# %%
#copying a small part of image to another part of the image
part=img1[280:340,330:390]
img1[273:333,100:160]=part
cv2.imshow('image',img1)
cv2.waitKey(0)
cv2.destroyAllWindows()
