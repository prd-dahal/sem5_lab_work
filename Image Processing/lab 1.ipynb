# %%
#table of content
#lab 1
#opening an image and printing its shape
import numpy as np
import cv2
#load an image in grayscale
img=cv2.imread('images\opticalfb.jpg')
cv2.imshow("color",img)
img1=cv2.imread('images\opticalfb.jpg',0)
cv2.imshow("grayscale",img1)
while(True):
    key=cv2.waitKey(0)
    if(key==32):
        cv2.destroyAllWindows()
        break
    else:
        pass
print(np.shape(img1))
print(np.shape(img))
print(img[:,:,0])

# %%
#lab2
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
img=cv.imread('images\opticalfb.jpg',0)
ret,thresh1=cv.threshold(img,127,255,cv.THRESH_BINARY)
ret,thresh2=cv.threshold(img,127,255,cv.THRESH_BINARY_INV)
titles=['Original Image','BINARY',"Binary_INV"]
images=[img,thresh1,thresh2]
for i in range(3):
    plt.subplot(1,3,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %%
#lab3 
import cv2 
import numpy as np
img_1=cv2.imread('images\dft.jfif',0)

#converting into integer data type
img_2=np.uint8(np.log1p(img_1))
print(img_2.max())
thresh=1
img_3=cv2.threshold(img_2,thresh,255,cv2.THRESH_BINARY)[1]
cv2.imshow('input image',img_1)
cv2.imshow('log transformed',img_3)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 5

# %%
#lab 4
import cv2
import numpy as np
import matplotlib.pyplot as plt
img1=cv2.imread('images\leg.png',0)
gamma=2
img2=np.power(img1,gamma)
gamma=3
img3=np.power(img1,gamma)
gamma=4
img4=np.power(img1,gamma)

images=[img1,img2,img3,img4]
for i in range(4):
    plt.subplot(1,4,i+1),plt.imshow(images[i],'gray')
    plt.xticks([]),plt.yticks([])
plt.show()

# %%
#lab 5
import cv2
import numpy as np
import matplotlib.pyplot as plt
image1=cv2.imread('images\ImageLab\input1.jpg',0)
image2=cv2.imread('images\ImageLab\input2.jpg',0)
img1=cv2.resize(image1,(256,256))
img2=cv2.resize(image2,(256,256))
dest_and=cv2.bitwise_and(img2,img1,mask=None)

dest_or=cv2.bitwise_or(img2,img1,mask=None)

dest_XOR=cv2.bitwise_xor(img2,img1,mask=None)

dest_not2=cv2.bitwise_not(img2,mask=None)
dest_not1=cv2.bitwise_not(img1,mask=None)
images=[dest_and,dest_or,dest_XOR,dest_not1,dest_not2]
label=['AND','OR','XOR','NOT-1','NOT-2']
for i in range(5):
    plt.subplot(1,5,i+1),plt.imshow(images[i],'gray')
    plt.title(label[i])
    plt.xticks([]),plt.yticks([])

# %%
#lab6
import cv2
import numpy as np

img1 = cv2.imread('images\ImageLab\m1.png')
img2 = cv2.imread('images\ImageLab\opencv_logo.jpg')
print(img1.shape)
print(img2.shape)
img1=cv2.resize(img1,(256,256))
img2=cv2.resize(img2,(256,256))

tempAddedImage=cv2.addWeighted(img1,0.5,img2,0.5,0)
addedImage=cv2.resize(tempAddedImage,(500,500))
cv2.imshow(' Only Fav mentor ;)',addedImage)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (269, 242, 3)
# (264, 211, 3)
